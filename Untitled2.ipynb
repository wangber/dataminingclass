# %%
import numpy as np 
import pandas as pd #用于csv数据读入及后续处理
import matplotlib.pyplot as plt
import plotly.plotly as py
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go

from plotly import tools
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import os
print('当前路径下文件：'+str(os.listdir("/data")))#列出当前路径下的文件列表
lol=pd.read_csv("/data/jupyterenv/games.csv")
'''
data=lol[["winner","firstBlood","firstTower","firstInhibitor","firstBaron","firstDragon","firstRiftHerald","t1_towerKills","t1_inhibitorKills",'t1_baronKills',
       't1_dragonKills','t2_towerKills','t2_inhibitorKills', 't2_baronKills', 't2_dragonKills'
       ]]
'''
'''
data_new=data[["winner","t1_towerKills","t1_inhibitorKills","t1_baronKills","t1_dragonKills","t2_towerKills","t2_inhibitorKills","t2_baronKills","t2_dragonKills"]]
data_new.groupby("winner").mean()
'''
y = lol["winner"].values
x = lol.drop(["winner"],axis=1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state=1)
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
#选择最佳参数
'''
criterion=["gini","entropy"]
max_depth=range(1,20,2)
splitter=["best","random"]
dt=DecisionTreeClassifier()
grid_decision_tree=GridSearchCV(estimator=dt,cv=15,param_grid=dict(criterion=criterion,max_depth=max_depth,splitter=splitter))

grid_decision_tree.fit(x_train,y_train)
print("best score: ", grid_decision_tree.best_score_)
print("best param: ", grid_decision_tree.best_params_)
'''
#设置参数字典
pram={'criterion':'gini',
    'splitter':'best',
    'max_depth':'默认',
    'min_impurity_decrease':'默认',
    'min_samples_split':'默认',
    'min_impurity_split':'默认',

                  }
dt2=DecisionTreeClassifier(criterion=pram['criterion'], splitter=pram['splitter'])
dt2.fit(x_train,y_train)
print('当前参数：\n criterion={},\nsplitter={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
print("测试所得准确率:", dt2.score(x_test,y_test))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 当前路径下文件：['www', 'flask2.py', 'ssl', '24dian', 'jupyterenv']
# 当前参数：
#  criterion=gini,
# splitter=best
# min_impurity_decrease=默认
# min_samples_split=默认
# min_impurity_split=默认
# 测试所得准确率: 0.959862756522302

# %%
import numpy as np 
import pandas as pd #用于csv数据读入及后续处理
import matplotlib.pyplot as plt
import plotly.plotly as py
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go

from plotly import tools
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import os
print('当前路径下文件：'+str(os.listdir("/data")))#列出当前路径下的文件列表
lol=pd.read_csv("/data/jupyterenv/games.csv")
'''
data=lol[["winner","firstBlood","firstTower","firstInhibitor","firstBaron","firstDragon","firstRiftHerald","t1_towerKills","t1_inhibitorKills",'t1_baronKills',
       't1_dragonKills','t2_towerKills','t2_inhibitorKills', 't2_baronKills', 't2_dragonKills'
       ]]
'''
'''
data_new=data[["winner","t1_towerKills","t1_inhibitorKills","t1_baronKills","t1_dragonKills","t2_towerKills","t2_inhibitorKills","t2_baronKills","t2_dragonKills"]]
data_new.groupby("winner").mean()
'''
y = lol["winner"].values
x = lol.drop(["winner"],axis=1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state=1)
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
#选择最佳参数
'''
criterion=["gini","entropy"]
max_depth=range(1,20,2)
splitter=["best","random"]
dt=DecisionTreeClassifier()
grid_decision_tree=GridSearchCV(estimator=dt,cv=15,param_grid=dict(criterion=criterion,max_depth=max_depth,splitter=splitter))

grid_decision_tree.fit(x_train,y_train)
print("best score: ", grid_decision_tree.best_score_)
print("best param: ", grid_decision_tree.best_params_)
'''
#设置参数字典
pram={'criterion':'gini',
    'splitter':'best',
    'max_depth':'默认',
    'min_impurity_decrease':'默认',
    'min_samples_split':'默认',
    'min_impurity_split':'默认',

                  }
dep=[]
score=[]
for i in range(1,25,2):
    pram['max_depth']=i
    dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'])
    dt2.fit(x_train,y_train)
    print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
    print("测试所得准确率:", dt2.score(x_test,y_test))
    score.append(dt2.score(x_test,y_test))
    dep.append(i)
print(dep)
print(score)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 当前路径下文件：['www', 'flask2.py', 'ssl', '24dian', 'jupyterenv']
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=1
# min_impurity_decrease=默认
# min_samples_split=默认
# min_impurity_split=默认
# 测试所得准确率: 0.8874862432834855
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=3
# min_impurity_decrease=默认
# min_samples_split=默认
# min_impurity_split=默认
# 测试所得准确率: 0.9524179452320839
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=5
# ...

# %%
import numpy as np 
import pandas as pd #用于csv数据读入及后续处理
import matplotlib.pyplot as plt
import plotly.plotly as py
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go

from plotly import tools
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import os
print('当前路径下文件：'+str(os.listdir("/data")))#列出当前路径下的文件列表
lol=pd.read_csv("/data/jupyterenv/games.csv")
'''
data=lol[["winner","firstBlood","firstTower","firstInhibitor","firstBaron","firstDragon","firstRiftHerald","t1_towerKills","t1_inhibitorKills",'t1_baronKills',
       't1_dragonKills','t2_towerKills','t2_inhibitorKills', 't2_baronKills', 't2_dragonKills'
       ]]
'''
'''
data_new=data[["winner","t1_towerKills","t1_inhibitorKills","t1_baronKills","t1_dragonKills","t2_towerKills","t2_inhibitorKills","t2_baronKills","t2_dragonKills"]]
data_new.groupby("winner").mean()
'''
y = lol["winner"].values
x = lol.drop(["winner"],axis=1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state=1)
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
#选择最佳参数
'''
criterion=["gini","entropy"]
max_depth=range(1,20,2)
splitter=["best","random"]
dt=DecisionTreeClassifier()
grid_decision_tree=GridSearchCV(estimator=dt,cv=15,param_grid=dict(criterion=criterion,max_depth=max_depth,splitter=splitter))

grid_decision_tree.fit(x_train,y_train)
print("best score: ", grid_decision_tree.best_score_)
print("best param: ", grid_decision_tree.best_params_)
'''
#设置参数字典
pram={'criterion':'gini',
    'splitter':'best',
    'max_depth':7,
    'min_impurity_decrease':'默认',#节点划分最小不纯度
    'min_samples_split':'默认',#内部节点再划分所需最小样本数
    'min_impurity_split':'默认',#信息增益阙值

                  }
'''
for i in range(2,22,2):
    pram['max_depth']=i
    dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'])
    dt2.fit(x_train,y_train)
    print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
    print("测试所得准确率:", dt2.score(x_test,y_test))
'''
min_impurity_decrease=0
for i in range(1,30):
    pram['min_impurity_decrease']=min_impurity_decrease
    dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'],min_impurity_decrease=pram['min_impurity_decrease'])
    dt2.fit(x_train,y_train)
    print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
    print("测试所得准确率:", dt2.score(x_test,y_test))
    min_impurity_decrease+=0.05
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 当前路径下文件：['www', 'flask2.py', 'ssl', '24dian', 'jupyterenv']
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=7
# min_impurity_decrease=0
# min_samples_split=默认
# min_impurity_split=默认
# 测试所得准确率: 0.9669838803651194
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=7
# min_impurity_decrease=0.05
# min_samples_split=默认
# min_impurity_split=默认
# 测试所得准确率: 0.9249692496924969
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=7
# ...

# %%
import numpy as np 
import pandas as pd #用于csv数据读入及后续处理
import matplotlib.pyplot as plt
import plotly.plotly as py
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go

from plotly import tools
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import os
print('当前路径下文件：'+str(os.listdir("/data")))#列出当前路径下的文件列表
lol=pd.read_csv("/data/jupyterenv/games.csv")
'''
data=lol[["winner","firstBlood","firstTower","firstInhibitor","firstBaron","firstDragon","firstRiftHerald","t1_towerKills","t1_inhibitorKills",'t1_baronKills',
       't1_dragonKills','t2_towerKills','t2_inhibitorKills', 't2_baronKills', 't2_dragonKills'
       ]]
'''
'''
data_new=data[["winner","t1_towerKills","t1_inhibitorKills","t1_baronKills","t1_dragonKills","t2_towerKills","t2_inhibitorKills","t2_baronKills","t2_dragonKills"]]
data_new.groupby("winner").mean()
'''
y = lol["winner"].values
x = lol.drop(["winner"],axis=1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state=1)
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
#选择最佳参数
'''
criterion=["gini","entropy"]
max_depth=range(1,20,2)
splitter=["best","random"]
dt=DecisionTreeClassifier()
grid_decision_tree=GridSearchCV(estimator=dt,cv=15,param_grid=dict(criterion=criterion,max_depth=max_depth,splitter=splitter))

grid_decision_tree.fit(x_train,y_train)
print("best score: ", grid_decision_tree.best_score_)
print("best param: ", grid_decision_tree.best_params_)
'''
#设置参数字典
pram={'criterion':'gini',
    'splitter':'best',
    'max_depth':7,
    'min_impurity_decrease':0,#节点划分最小不纯度
    'min_samples_split':'默认',#内部节点再划分所需最小样本数
    'min_impurity_split':'默认',#信息增益阙值

                  }
#用于参数max_depth的测试                  
'''
for i in range(2,22,2):
    pram['max_depth']=i
    dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'])
    dt2.fit(x_train,y_train)
    print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
    print("测试所得准确率:", dt2.score(x_test,y_test))
'''
#用于参数min_impurity_decrease的测试
'''
min_impurity_decrease=0
for i in range(1,30):
    pram['min_impurity_decrease']=min_impurity_decrease
    dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'],min_impurity_decrease=pram['min_impurity_decrease'])
    dt2.fit(x_train,y_train)
    print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
    print("测试所得准确率:", dt2.score(x_test,y_test))
    min_impurity_decrease+=0.1
'''
#用于min_impurity_split参数的测试
min_impurity_split=0
for i in range(1,30):
    pram['min_impurity_split']=min_impurity_split
    dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'],min_impurity_decrease=pram['min_impurity_decrease'],min_impurity_split=pram['min_impurity_split'])
    dt2.fit(x_train,y_train)
    print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
    print("测试所得准确率:", dt2.score(x_test,y_test))
    min_impurity_split+=0.1
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 当前路径下文件：['www', 'flask2.py', 'ssl', '24dian', 'jupyterenv']
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=7
# min_impurity_decrease=0
# min_samples_split=默认
# min_impurity_split=0
# 测试所得准确率: 0.9668544053861591
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=7
# min_impurity_decrease=0
# min_samples_split=默认
# min_impurity_split=0.1
# 测试所得准确率: 0.9588916941800997
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=7
# ...

# %%
import numpy as np 
import pandas as pd #用于csv数据读入及后续处理
import matplotlib.pyplot as plt
import plotly.plotly as py
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go

from plotly import tools
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import os
print('当前路径下文件：'+str(os.listdir("/data")))#列出当前路径下的文件列表
lol=pd.read_csv("/data/jupyterenv/games.csv")
'''
data=lol[["winner","firstBlood","firstTower","firstInhibitor","firstBaron","firstDragon","firstRiftHerald","t1_towerKills","t1_inhibitorKills",'t1_baronKills',
       't1_dragonKills','t2_towerKills','t2_inhibitorKills', 't2_baronKills', 't2_dragonKills'
       ]]
'''
'''
data_new=data[["winner","t1_towerKills","t1_inhibitorKills","t1_baronKills","t1_dragonKills","t2_towerKills","t2_inhibitorKills","t2_baronKills","t2_dragonKills"]]
data_new.groupby("winner").mean()
'''
y = lol["winner"].values
x = lol.drop(["winner"],axis=1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state=1)
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
#选择最佳参数
'''
criterion=["gini","entropy"]
max_depth=range(1,20,2)
splitter=["best","random"]
dt=DecisionTreeClassifier()
grid_decision_tree=GridSearchCV(estimator=dt,cv=15,param_grid=dict(criterion=criterion,max_depth=max_depth,splitter=splitter))

grid_decision_tree.fit(x_train,y_train)
print("best score: ", grid_decision_tree.best_score_)
print("best param: ", grid_decision_tree.best_params_)
'''
#设置参数字典
pram={'criterion':'gini',
    'splitter':'best',
    'max_depth':7,
    'min_impurity_decrease':0,#节点划分最小不纯度
    'min_samples_split':'默认',#内部节点再划分所需最小样本数
    'min_impurity_split':0.1,#信息增益阙值

                  }
#用于参数max_depth的测试                  
'''
for i in range(2,22,2):
    pram['max_depth']=i
    dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'])
    dt2.fit(x_train,y_train)
    print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
    print("测试所得准确率:", dt2.score(x_test,y_test))
'''
#用于参数min_impurity_decrease的测试
'''
min_impurity_decrease=0
for i in range(1,30):
    pram['min_impurity_decrease']=min_impurity_decrease
    dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'],min_impurity_decrease=pram['min_impurity_decrease'])
    dt2.fit(x_train,y_train)
    print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
    print("测试所得准确率:", dt2.score(x_test,y_test))
    min_impurity_decrease+=0.1
'''
#用于min_impurity_split参数的测试
'''
min_impurity_split=0
for i in range(1,30):
    pram['min_impurity_decrease']=min_impurity_split
    dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'],min_impurity_decrease=pram['min_impurity_decrease'],min_impurity_split=pram['min_impurity_split'])
    dt2.fit(x_train,y_train)
    print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
    print("测试所得准确率:", dt2.score(x_test,y_test))
    min_impurity_decrease+=0.1
'''

#用于
dt2=DecisionTreeClassifier(criterion=pram['criterion'], max_depth=pram['max_depth'],splitter=pram['splitter'],min_impurity_decrease=pram['min_impurity_decrease'],min_impurity_split=pram['min_impurity_split'])
dt2.fit(x_train,y_train)
print('当前参数：\n criterion={},\nsplitter={}\nmax_depth={}\nmin_impurity_decrease={}\nmin_samples_split={}\nmin_impurity_split={}'.format(pram['criterion'],pram['splitter'],pram['max_depth'],pram['min_impurity_decrease'],pram['min_samples_split'],pram['min_impurity_split'],))
print("测试所得准确率:", dt2.score(x_test,y_test))
print(dt2.get_params())
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 当前路径下文件：['www', 'flask2.py', 'ssl', '24dian', 'jupyterenv']
# 当前参数：
#  criterion=gini,
# splitter=best
# max_depth=7
# min_impurity_decrease=0
# min_samples_split=默认
# min_impurity_split=0.1
# 测试所得准确率: 0.9588916941800997
# ...

# %%
from sklearn import tree
import graphviz 
dot_data = tree.export_graphviz(dt2, out_file=None, feature_names=x.columns,class_names=["1","2"], 
                     filled=True, rounded=True, special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
